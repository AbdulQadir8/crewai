# %%
# !pip install -q -U crewai crewai-tools
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.1/252.1 kB 9.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 73.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.5/548.5 kB 28.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 9.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 65.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 10.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.4/211.4 kB 13.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 628.3/628.3 kB 33.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 5.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.2/33.2 MB 34.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.1/65.1 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.9/55.9 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.9/118.9 kB 8.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.4/183.4 kB 12.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 4.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 71.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 68.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 28.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.0/236.0 kB 15.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.2/16.2 MB 54.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 231.8/231.8 kB 14.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.2/284.2 kB 17.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.9/253.9 kB 15.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.9/94.9 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.6/131.6 kB 8.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 55.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 59.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.8/311.8 kB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.9/106.9 kB 8.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 7.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 23.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 6.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.8/36.8 MB 22.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 69.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.1/71.1 kB 5.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 52.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 72.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 80.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 459.8/459.8 kB 29.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 66.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.2/209.2 kB 17.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 22.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 75.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.0/508.0 kB 30.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.7/306.7 kB 21.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 81.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.6/452.6 kB 30.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 63.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 69.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 3.5 MB/s eta 0:00:00
#   Building wheel for pypika (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-genai 1.4.0 requires httpx<1.0.0dev,>=0.28.1, but you have httpx 0.27.2 which is incompatible.
# transformers 4.48.3 requires tokenizers<0.22,>=0.21, but you have tokenizers 0.20.3 which is incompatible.

# %%
import os
from google.colab import userdata

os.environ["GEMINI_API_KEY"] = userdata.get('GEMINI_API_KEY')
os.environ["MODEL"] = "gemini/gemini-2.0-flash"

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# !crewai create crew pr1
# Out:
# Creating folder pr1...
# Cache expired or not found. Fetching provider data from the web...
# Downloading  [####################################]  370866/17831
# Select a provider to set up:
# 1. openai
# 2. anthropic
# 3. gemini
# 4. nvidia_nim
# 5. groq
# 6. ollama
# 7. watson
# 8. bedrock
# 9. azure
# 10. cerebras
# 11. sambanova
# 12. other
# q. Quit
# Enter the number of your choice or 'q' to quit: 3
# Select a model to use for Gemini:
# 1. gemini/gemini-1.5-flash
# 2. gemini/gemini-1.5-pro
# 3. gemini/gemini-gemma-2-9b-it
# 4. gemini/gemini-gemma-2-27b-it
# q. Quit
# Enter the number of your choice or 'q' to quit: 1
# Enter your GEMINI API key (press Enter to skip): AIzaSyDkN3d3qmlUvn2rO-HqxDI6HlNgHeiYRvE
# API keys and model saved to .env file
# Selected model: gemini/gemini-1.5-flash
#   - Created pr1/.gitignore
#   - Created pr1/pyproject.toml
#   - Created pr1/README.md
#   - Created pr1/knowledge/user_preference.txt
#   - Created pr1/src/pr1/__init__.py
#   - Created pr1/src/pr1/main.py
#   - Created pr1/src/pr1/crew.py
#   - Created pr1/src/pr1/tools/custom_tool.py
#   - Created pr1/src/pr1/tools/__init__.py
#   - Created pr1/src/pr1/config/agents.yaml
#   - Created pr1/src/pr1/config/tasks.yaml
# Crew pr1 created successfully!

# %%
# !pwd
# Out:
# /content

# %%
# !cd pr1

# %%
# !pwd
# Out:
# /content

# %%
# %cd pr1/
# Out:
# /content/pr1

# %%
# %ls
# Out:
# knowledge/  pyproject.toml  README.md  src/  tests/

# %%
'''Python Initial code /content/pr1/src/pr1/crew.py

from crewai import Agent, Crew, Process, Task
from crewai.project import CrewBase, agent, crew, task

# If you want to run a snippet of code before or after the crew starts,
# you can use the @before_kickoff and @after_kickoff decorators
# https://docs.crewai.com/concepts/crews#example-crew-class-with-decorators

@CrewBase
class Pr1():
	"""Pr1 crew"""

	# Learn more about YAML configuration files here:
	# Agents: https://docs.crewai.com/concepts/agents#yaml-configuration-recommended
	# Tasks: https://docs.crewai.com/concepts/tasks#yaml-configuration-recommended
	agents_config = 'config/agents.yaml'
	tasks_config = 'config/tasks.yaml'

	# If you would like to add tools to your agents, you can learn more about it here:
	# https://docs.crewai.com/concepts/agents#agent-tools
	@agent
	def researcher(self) -> Agent:
		return Agent(
			config=self.agents_config['researcher'],
			verbose=True
		)

	@agent
	def reporting_analyst(self) -> Agent:
		return Agent(
			config=self.agents_config['reporting_analyst'],
			verbose=True
		)

	# To learn more about structured task outputs,
	# task dependencies, and task callbacks, check out the documentation:
	# https://docs.crewai.com/concepts/tasks#overview-of-a-task
	@task
	def research_task(self) -> Task:
		return Task(
			config=self.tasks_config['research_task'],
		)

	@task
	def reporting_task(self) -> Task:
		return Task(
			config=self.tasks_config['reporting_task'],
			output_file='report.md'
		)

	@crew
	def crew(self) -> Crew:
		"""Creates the Pr1 crew"""
		# To learn how to add knowledge sources to your crew, check out the documentation:
		# https://docs.crewai.com/concepts/knowledge#what-is-knowledge

		return Crew(
			agents=self.agents, # Automatically created by the @agent decorator
			tasks=self.tasks, # Automatically created by the @task decorator
			process=Process.sequential,
			verbose=True,

			# process=Process.hierarchical, # In case you wanna use that instead https://docs.crewai.com/how-to/Hierarchical/
		)


'''
# Out:
# 'Python Initial code /content/pr1/src/pr1/crew.py\n\nfrom crewai import Agent, Crew, Process, Task\nfrom crewai.project import CrewBase, agent, crew, task\n\n# If you want to run a snippet of code before or after the crew starts,\n# you can use the @before_kickoff and @after_kickoff decorators\n# https://docs.crewai.com/concepts/crews#example-crew-class-with-decorators\n\n@CrewBase\nclass Pr1():\n\t"""Pr1 crew"""\n\n\t# Learn more about YAML configuration files here:\n\t# Agents: https://docs.crewai.com/concepts/agents#yaml-configuration-recommended\n\t# Tasks: https://docs.crewai.com/concepts/tasks#yaml-configuration-recommended\n\tagents_config = \'config/agents.yaml\'\n\ttasks_config = \'config/tasks.yaml\'\n\n\t# If you would like to add tools to your agents, you can learn more about it here:\n\t# https://docs.crewai.com/concepts/agents#agent-tools\n\t@agent\n\tdef researcher(self) -> Agent:\n\t\treturn Agent(\n\t\t\tconfig=self.agents_config[\'researcher\'],\n\t\t\tverbose=True\n\t\t)\n\n\t@agent\n\tdef reporting_analyst(self) -> Agent:\n\t\treturn Agent(\n\t\t\tconfig=self.agents_config[\'reporting_analyst\'],\n\t\t\tverbose=True\n\t\t)\n\n\t# To learn more about structured task outputs,\n\t# task dependencies, and task callbacks, check out the documentation:\n\t# https://docs.crewai.com/concepts/tasks#overview-of-a-task\n\t@task\n\tdef research_task(self) -> Task:\n\t\treturn Task(\n\t\t\tconfig=self.tasks_config[\'research_task\'],\n\t\t)\n\n\t@task\n\tdef reporting_task(self) -> Task:\n\t\treturn Task(\n\t\t\tconfig=self.tasks_config[\'reporting_task\'],\n\t\t\toutput_file=\'report.md\'\n\t\t)\n\n\t@crew\n\tdef crew(self) -> Crew:\n\t\t"""Creates the Pr1 crew"""\n\t\t# To learn how to add knowledge sources to your crew, check out the documentation:\n\t\t# https://docs.crewai.com/concepts/knowledge#what-is-knowledge\n\n\t\treturn Crew(\n\t\t\tagents=self.agents, # Automatically created by the @agent decorator\n\t\t\ttasks=self.tasks, # Automatically created by the @task decorator\n\t\t\tprocess=Process.sequential,\n\t\t\tverbose=True,\n\n\t\t\t# process=Process.hierarchical, # In case you wanna use that instead https://docs.crewai.com/how-to/Hierarchical/\n\t\t)\n\n\n'

# %%
# !crewai run

# %%
'''python updated code  /content/pr1/src/pr1/crew.py

from crewai import Agent, Crew, Process, Task, LLM
from crewai.project import CrewBase, agent, crew, task

planning_llm=LLM(model="gemini/gemini-1.5-flash")

# If you want to run a snippet of code before or after the crew starts,
# you can use the @before_kickoff and @after_kickoff decorators
# https://docs.crewai.com/concepts/crews#example-crew-class-with-decorators

@CrewBase
class Pr1():
	"""Pr1 crew"""

	# Learn more about YAML configuration files here:
	# Agents: https://docs.crewai.com/concepts/agents#yaml-configuration-recommended
	# Tasks: https://docs.crewai.com/concepts/tasks#yaml-configuration-recommended
	agents_config = 'config/agents.yaml'
	tasks_config = 'config/tasks.yaml'

	# If you would like to add tools to your agents, you can learn more about it here:
	# https://docs.crewai.com/concepts/agents#agent-tools
	@agent
	def researcher(self) -> Agent:
		return Agent(
			config=self.agents_config['researcher'],
			verbose=True
		)

	@agent
	def reporting_analyst(self) -> Agent:
		return Agent(
			config=self.agents_config['reporting_analyst'],
			verbose=True
		)

	# To learn more about structured task outputs,
	# task dependencies, and task callbacks, check out the documentation:
	# https://docs.crewai.com/concepts/tasks#overview-of-a-task
	@task
	def research_task(self) -> Task:
		return Task(
			config=self.tasks_config['research_task'],
		)

	@task
	def reporting_task(self) -> Task:
		return Task(
			config=self.tasks_config['reporting_task'],
			output_file='report.md'
		)

	@crew
	def crew(self) -> Crew:
		"""Creates the Pr1 crew"""
		# To learn how to add knowledge sources to your crew, check out the documentation:
		# https://docs.crewai.com/concepts/knowledge#what-is-knowledge

		return Crew(
			agents=self.agents, # Automatically created by the @agent decorator
			tasks=self.tasks, # Automatically created by the @task decorator
			process=Process.sequential,
      planning=True,
      planning_llm=planning_llm,
			verbose=True,

			# process=Process.hierarchical, # In case you wanna use that instead https://docs.crewai.com/how-to/Hierarchical/
		)


'''
# Out:
# 'python updated code  /content/pr1/src/pr1/crew.py\n\nfrom crewai import Agent, Crew, Process, Task, LLM\nfrom crewai.project import CrewBase, agent, crew, task\n\nplanning_llm=LLM(model="gemini/gemini-1.5-flash")\n\n# If you want to run a snippet of code before or after the crew starts,\n# you can use the @before_kickoff and @after_kickoff decorators\n# https://docs.crewai.com/concepts/crews#example-crew-class-with-decorators\n\n@CrewBase\nclass Pr1():\n\t"""Pr1 crew"""\n\n\t# Learn more about YAML configuration files here:\n\t# Agents: https://docs.crewai.com/concepts/agents#yaml-configuration-recommended\n\t# Tasks: https://docs.crewai.com/concepts/tasks#yaml-configuration-recommended\n\tagents_config = \'config/agents.yaml\'\n\ttasks_config = \'config/tasks.yaml\'\n\n\t# If you would like to add tools to your agents, you can learn more about it here:\n\t# https://docs.crewai.com/concepts/agents#agent-tools\n\t@agent\n\tdef researcher(self) -> Agent:\n\t\treturn Agent(\n\t\t\tconfig=self.agents_config[\'researcher\'],\n\t\t\tverbose=True\n\t\t)\n\n\t@agent\n\tdef reporting_analyst(self) -> Agent:\n\t\treturn Agent(\n\t\t\tconfig=self.agents_config[\'reporting_analyst\'],\n\t\t\tverbose=True\n\t\t)\n\n\t# To learn more about structured task outputs,\n\t# task dependencies, and task callbacks, check out the documentation:\n\t# https://docs.crewai.com/concepts/tasks#overview-of-a-task\n\t@task\n\tdef research_task(self) -> Task:\n\t\treturn Task(\n\t\t\tconfig=self.tasks_config[\'research_task\'],\n\t\t)\n\n\t@task\n\tdef reporting_task(self) -> Task:\n\t\treturn Task(\n\t\t\tconfig=self.tasks_config[\'reporting_task\'],\n\t\t\toutput_file=\'report.md\'\n\t\t)\n\n\t@crew\n\tdef crew(self) -> Crew:\n\t\t"""Creates the Pr1 crew"""\n\t\t# To learn how to add knowledge sources to your crew, check out the documentation:\n\t\t# https://docs.crewai.com/concepts/knowledge#what-is-knowledge\n\n\t\treturn Crew(\n\t\t\tagents=self.agents, # Automatically created by the @agent decorator\n\t\t\ttasks=self.tasks, # Automatically created by the @task decorator\n\t\t\tprocess=Process.sequential,\n      planning=True,\n      planning_llm=planning_llm,\n\t\t\tverbose=True,\n\n\t\t\t# process=Process.hierarchical, # In case you wanna use that instead https://docs.crewai.com/how-to/Hierarchical/\n\t\t)\n\n\n'

# %%
#Updated code with planning result
# !crewai run
# Out:
# Streaming output truncated to the last 5000 lines.
# shapely    ------------------------------ 2.24 MiB/2.41 MiB
#    Building pr1 @ file:///content/pr1
# ⠦ Preparing packages... (105/214)
# pydantic-settings ------------------------------ 14.90 KiB/30.12 KiB
# flatbuffers ------------------------------ 16.00 KiB/30.23 KiB
# opentelemetry-instrumentation ------------------------------ 30.31 KiB/30.31 KiB
# langchain-text-splitters ------------------------------ 30.47 KiB/30.47 KiB
# google-crc32c ------------------------------ 14.90 KiB/31.73 KiB
# json5      ------------------------------ 16.00 KiB/33.25 KiB
# rsa        ------------------------------ 33.51 KiB/33.51 KiB
# hpack      ------------------------------ 16.00 KiB/33.55 KiB
# tabulate   ------------------------------ 34.43 KiB/34.43 KiB
# docstring-parser ------------------------------ 16.00 KiB/35.68 KiB
# importlib-resources ------------------------------ 36.58 KiB/36.58 KiB
# requests-toolbelt ------------------------------ 48.00 KiB/53.20 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 477.77 KiB/987.87 KiB
# jedi       ------------------------------ 525.38 KiB/1.50 MiB
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.21 MiB/2.30 MiB
# grpcio-tools ------------------------------ 2.23 MiB/2.36 MiB
# langchain-community ------------------------------ 1.14 MiB/2.41 MiB
# shapely    ------------------------------ 2.24 MiB/2.41 MiB
# pypdfium2  ------------------------------ 2.34 MiB/2.73 MiB
#    Building pr1 @ file:///content/pr1
# ⠦ Preparing packages... (105/214)
# pydantic-settings ------------------------------ 14.90 KiB/30.12 KiB
# flatbuffers ------------------------------ 16.00 KiB/30.23 KiB
# opentelemetry-instrumentation ------------------------------ 30.31 KiB/30.31 KiB
# langchain-text-splitters ------------------------------ 30.47 KiB/30.47 KiB
# google-crc32c ------------------------------ 14.90 KiB/31.73 KiB
# json5      ------------------------------ 16.00 KiB/33.25 KiB
# rsa        ------------------------------ 33.51 KiB/33.51 KiB
# hpack      ------------------------------ 16.00 KiB/33.55 KiB
# docstring-parser ------------------------------ 16.00 KiB/35.68 KiB
# importlib-resources ------------------------------ 36.58 KiB/36.58 KiB
# requests-toolbelt ------------------------------ 48.00 KiB/53.20 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 477.77 KiB/987.87 KiB
# jedi       ------------------------------ 525.38 KiB/1.50 MiB
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.21 MiB/2.30 MiB
# grpcio-tools ------------------------------ 2.23 MiB/2.36 MiB
# langchain-community ------------------------------ 1.14 MiB/2.41 MiB
# shapely    ------------------------------ 2.24 MiB/2.41 MiB
# pypdfium2  ------------------------------ 2.34 MiB/2.73 MiB
# tokenizers ------------------------------ 2.19 MiB/2.86 MiB
#    Building pr1 @ file:///content/pr1
# ⠦ Preparing packages... (105/214)
# pydantic-settings ------------------------------ 14.90 KiB/30.12 KiB
# flatbuffers ------------------------------ 16.00 KiB/30.23 KiB
# opentelemetry-instrumentation ------------------------------ 30.31 KiB/30.31 KiB
# langchain-text-splitters ------------------------------ 30.47 KiB/30.47 KiB
# google-crc32c ------------------------------ 14.90 KiB/31.73 KiB
# json5      ------------------------------ 16.00 KiB/33.25 KiB
# hpack      ------------------------------ 32.00 KiB/33.55 KiB
# docstring-parser ------------------------------ 16.00 KiB/35.68 KiB
# importlib-resources ------------------------------ 36.58 KiB/36.58 KiB
# requests-toolbelt ------------------------------ 53.20 KiB/53.20 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 477.77 KiB/987.87 KiB
# jedi       ------------------------------ 525.38 KiB/1.50 MiB
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.21 MiB/2.30 MiB
# grpcio-tools ------------------------------ 2.23 MiB/2.36 MiB
# langchain-community ------------------------------ 1.14 MiB/2.41 MiB
# shapely    ------------------------------ 2.24 MiB/2.41 MiB
# pypdfium2  ------------------------------ 2.34 MiB/2.73 MiB
# tokenizers ------------------------------ 2.19 MiB/2.86 MiB
# psycopg2-binary ------------------------------ 2.30 MiB/2.88 MiB
#    Building pr1 @ file:///content/pr1
# ⠦ Preparing packages... (105/214)
# pydantic-settings ------------------------------ 30.12 KiB/30.12 KiB
# flatbuffers ------------------------------ 16.00 KiB/30.23 KiB
# opentelemetry-instrumentation ------------------------------ 30.31 KiB/30.31 KiB
# langchain-text-splitters ------------------------------ 30.47 KiB/30.47 KiB
# google-crc32c ------------------------------ 14.90 KiB/31.73 KiB
# json5      ------------------------------ 16.00 KiB/33.25 KiB
# hpack      ------------------------------ 32.00 KiB/33.55 KiB
# docstring-parser ------------------------------ 16.00 KiB/35.68 KiB
# importlib-resources ------------------------------ 36.58 KiB/36.58 KiB
# requests-toolbelt ------------------------------ 53.20 KiB/53.20 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 477.77 KiB/987.87 KiB
# jedi       ------------------------------ 525.38 KiB/1.50 MiB
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.21 MiB/2.30 MiB
# grpcio-tools ------------------------------ 2.23 MiB/2.36 MiB
# langchain-community ------------------------------ 1.14 MiB/2.41 MiB
# shapely    ------------------------------ 2.24 MiB/2.41 MiB
# pypdfium2  ------------------------------ 2.34 MiB/2.73 MiB
# tokenizers ------------------------------ 2.19 MiB/2.86 MiB
# psycopg2-binary ------------------------------ 2.30 MiB/2.88 MiB
#    Building pr1 @ file:///content/pr1
# ⠦ Preparing packages... (105/214)
# pydantic-settings ------------------------------ 30.12 KiB/30.12 KiB
# flatbuffers ------------------------------ 16.00 KiB/30.23 KiB
# opentelemetry-instrumentation ------------------------------ 30.31 KiB/30.31 KiB
# langchain-text-splitters ------------------------------ 30.47 KiB/30.47 KiB
# google-crc32c ------------------------------ 14.90 KiB/31.73 KiB
# json5      ------------------------------ 16.00 KiB/33.25 KiB
# hpack      ------------------------------ 32.00 KiB/33.55 KiB
# docstring-parser ------------------------------ 16.00 KiB/35.68 KiB
# importlib-resources ------------------------------ 36.58 KiB/36.58 KiB
# requests-toolbelt ------------------------------ 53.20 KiB/53.20 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 477.77 KiB/987.87 KiB
# jedi       ------------------------------ 525.38 KiB/1.50 MiB
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.21 MiB/2.30 MiB
# grpcio-tools ------------------------------ 2.23 MiB/2.36 MiB
# langchain-community ------------------------------ 1.14 MiB/2.41 MiB
# shapely    ------------------------------ 2.24 MiB/2.41 MiB
# pypdfium2  ------------------------------ 2.34 MiB/2.73 MiB
# tokenizers ------------------------------ 2.19 MiB/2.86 MiB
# psycopg2-binary ------------------------------ 2.30 MiB/2.88 MiB
#    Building pr1 @ file:///content/pr1
# ⠦ Preparing packages... (105/214)
# referencing ------------------------------     0 B/26.15 KiB
# asttokens  ------------------------------     0 B/26.29 KiB
# importlib-metadata ------------------------------     0 B/26.34 KiB
# tenacity   ------------------------------     0 B/27.51 KiB
# dataclasses-json ------------------------------     0 B/28.01 KiB
# google-cloud-core ------------------------------     0 B/28.66 KiB
# pydantic-settings ------------------------------ 30.12 KiB/30.12 KiB
# flatbuffers ------------------------------ 16.00 KiB/30.23 KiB
# opentelemetry-instrumentation ------------------------------ 30.31 KiB/30.31 KiB
# langchain-text-splitters ------------------------------ 30.47 KiB/30.47 KiB
# google-crc32c ------------------------------ 30.90 KiB/31.73 KiB
# json5      ------------------------------ 16.00 KiB/33.25 KiB
# hpack      ------------------------------ 32.00 KiB/33.55 KiB
# docstring-parser ------------------------------ 16.00 KiB/35.68 KiB
# importlib-resources ------------------------------ 36.58 KiB/36.58 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 493.66 KiB/987.87 KiB
# jedi       ------------------------------ 525.38 KiB/1.50 MiB
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.22 MiB/2.30 MiB
# grpcio-tools ------------------------------ 2.25 MiB/2.36 MiB
#    Building pr1 @ file:///content/pr1
# ⠦ Preparing packages... (105/214)
# referencing ------------------------------     0 B/26.15 KiB
# asttokens  ------------------------------     0 B/26.29 KiB
# importlib-metadata ------------------------------     0 B/26.34 KiB
# tenacity   ------------------------------     0 B/27.51 KiB
# dataclasses-json ------------------------------     0 B/28.01 KiB
# google-cloud-core ------------------------------     0 B/28.66 KiB
# pydantic-settings ------------------------------ 30.12 KiB/30.12 KiB
# flatbuffers ------------------------------ 16.00 KiB/30.23 KiB
# langchain-text-splitters ------------------------------ 30.47 KiB/30.47 KiB
# google-crc32c ------------------------------ 30.90 KiB/31.73 KiB
# json5      ------------------------------ 16.00 KiB/33.25 KiB
# hpack      ------------------------------ 32.00 KiB/33.55 KiB
# docstring-parser ------------------------------ 32.00 KiB/35.68 KiB
# importlib-resources ------------------------------ 36.58 KiB/36.58 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 493.66 KiB/987.87 KiB
# jedi       ------------------------------ 525.38 KiB/1.50 MiB
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.22 MiB/2.30 MiB
# grpcio-tools ------------------------------ 2.25 MiB/2.36 MiB
# langchain-community ------------------------------ 1.14 MiB/2.41 MiB
#    Building pr1 @ file:///content/pr1
# ⠦ Preparing packages... (105/214)
# stack-data ------------------------------     0 B/23.95 KiB
# executing  ------------------------------     0 B/26.08 KiB
# referencing ------------------------------ 14.88 KiB/26.15 KiB
# asttokens  ------------------------------ 14.88 KiB/26.29 KiB
# importlib-metadata ------------------------------ 14.87 KiB/26.34 KiB
# tenacity   ------------------------------ 14.88 KiB/27.51 KiB
# dataclasses-json ------------------------------ 14.87 KiB/28.01 KiB
# google-cloud-core ------------------------------ 14.87 KiB/28.66 KiB
# pydantic-settings ------------------------------ 30.12 KiB/30.12 KiB
# flatbuffers ------------------------------ 30.23 KiB/30.23 KiB
# langchain-text-splitters ------------------------------ 30.47 KiB/30.47 KiB
# google-crc32c ------------------------------ 30.90 KiB/31.73 KiB
# json5      ------------------------------ 16.00 KiB/33.25 KiB
# hpack      ------------------------------ 32.00 KiB/33.55 KiB
# docstring-parser ------------------------------ 32.00 KiB/35.68 KiB
# importlib-resources ------------------------------ 36.58 KiB/36.58 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 493.66 KiB/987.87 KiB
# jedi       ------------------------------ 525.38 KiB/1.50 MiB
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.24 MiB/2.30 MiB
#    Building pr1 @ file:///content/pr1
# ⠦ Preparing packages... (105/214)
# asgiref    ------------------------------     0 B/23.27 KiB
# requests-oauthlib ------------------------------     0 B/23.61 KiB
# stack-data ------------------------------ 16.00 KiB/23.95 KiB
# executing  ------------------------------ 16.00 KiB/26.08 KiB
# referencing ------------------------------ 14.88 KiB/26.15 KiB
# asttokens  ------------------------------ 26.29 KiB/26.29 KiB
# importlib-metadata ------------------------------ 14.87 KiB/26.34 KiB
# tenacity   ------------------------------ 14.88 KiB/27.51 KiB
# dataclasses-json ------------------------------ 14.87 KiB/28.01 KiB
# google-cloud-core ------------------------------ 14.87 KiB/28.66 KiB
# pydantic-settings ------------------------------ 30.12 KiB/30.12 KiB
# flatbuffers ------------------------------ 30.23 KiB/30.23 KiB
# google-crc32c ------------------------------ 30.90 KiB/31.73 KiB
# json5      ------------------------------ 32.00 KiB/33.25 KiB
# hpack      ------------------------------ 32.00 KiB/33.55 KiB
# docstring-parser ------------------------------ 32.00 KiB/35.68 KiB
# importlib-resources ------------------------------ 36.58 KiB/36.58 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 493.66 KiB/987.87 KiB
# jedi       ------------------------------ 525.38 KiB/1.50 MiB
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
#    Building pr1 @ file:///content/pr1
# ⠦ Preparing packages... (105/214)
# asgiref    ------------------------------     0 B/23.27 KiB
# requests-oauthlib ------------------------------     0 B/23.61 KiB
# stack-data ------------------------------ 16.00 KiB/23.95 KiB
# executing  ------------------------------ 16.00 KiB/26.08 KiB
# referencing ------------------------------ 14.88 KiB/26.15 KiB
# asttokens  ------------------------------ 26.29 KiB/26.29 KiB
# importlib-metadata ------------------------------ 14.87 KiB/26.34 KiB
# tenacity   ------------------------------ 14.88 KiB/27.51 KiB
# dataclasses-json ------------------------------ 14.87 KiB/28.01 KiB
# google-cloud-core ------------------------------ 14.87 KiB/28.66 KiB
# pydantic-settings ------------------------------ 30.12 KiB/30.12 KiB
# flatbuffers ------------------------------ 30.23 KiB/30.23 KiB
# google-crc32c ------------------------------ 30.90 KiB/31.73 KiB
# json5      ------------------------------ 32.00 KiB/33.25 KiB
# hpack      ------------------------------ 32.00 KiB/33.55 KiB
# docstring-parser ------------------------------ 32.00 KiB/35.68 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 493.66 KiB/987.87 KiB
# jedi       ------------------------------ 525.38 KiB/1.50 MiB
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.25 MiB/2.30 MiB
#    Building pr1 @ file:///content/pr1
# ⠦ Preparing packages... (105/214)
# asgiref    ------------------------------     0 B/23.27 KiB
# requests-oauthlib ------------------------------     0 B/23.61 KiB
# stack-data ------------------------------ 16.00 KiB/23.95 KiB
# executing  ------------------------------ 16.00 KiB/26.08 KiB
# referencing ------------------------------ 14.88 KiB/26.15 KiB
# asttokens  ------------------------------ 26.29 KiB/26.29 KiB
# importlib-metadata ------------------------------ 14.87 KiB/26.34 KiB
# tenacity   ------------------------------ 14.88 KiB/27.51 KiB
# dataclasses-json ------------------------------ 14.87 KiB/28.01 KiB
# google-cloud-core ------------------------------ 28.66 KiB/28.66 KiB
# pydantic-settings ------------------------------ 30.12 KiB/30.12 KiB
# flatbuffers ------------------------------ 30.23 KiB/30.23 KiB
# google-crc32c ------------------------------ 30.90 KiB/31.73 KiB
# json5      ------------------------------ 32.00 KiB/33.25 KiB
# hpack      ------------------------------ 32.00 KiB/33.55 KiB
# docstring-parser ------------------------------ 32.00 KiB/35.68 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 493.66 KiB/987.87 KiB
# jedi       ------------------------------ 525.38 KiB/1.50 MiB
# kubernetes ------------------------------ 1.43 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.25 MiB/2.30 MiB
#    Building pr1 @ file:///content/pr1
# ⠧ Preparing packages... (114/214)
# build      ------------------------------     0 B/22.41 KiB
# markupsafe ------------------------------ 16.00 KiB/22.58 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# stack-data ------------------------------ 16.00 KiB/23.95 KiB
# executing  ------------------------------ 16.00 KiB/26.08 KiB
# referencing ------------------------------ 20.24 KiB/26.15 KiB
# asttokens  ------------------------------ 26.29 KiB/26.29 KiB
# importlib-metadata ------------------------------ 14.87 KiB/26.34 KiB
# tenacity   ------------------------------ 14.88 KiB/27.51 KiB
# dataclasses-json ------------------------------ 14.87 KiB/28.01 KiB
# google-cloud-core ------------------------------ 28.66 KiB/28.66 KiB
# flatbuffers ------------------------------ 30.23 KiB/30.23 KiB
# google-crc32c ------------------------------ 30.90 KiB/31.73 KiB
# json5      ------------------------------ 32.00 KiB/33.25 KiB
# hpack      ------------------------------ 32.00 KiB/33.55 KiB
# docstring-parser ------------------------------ 32.00 KiB/35.68 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 493.66 KiB/987.87 KiB
# jedi       ------------------------------ 525.38 KiB/1.50 MiB
# kubernetes ------------------------------ 1.45 MiB/1.90 MiB
#    Building pr1 @ file:///content/pr1
# ⠧ Preparing packages... (114/214)
# build      ------------------------------     0 B/22.41 KiB
# markupsafe ------------------------------ 16.00 KiB/22.58 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# stack-data ------------------------------ 16.00 KiB/23.95 KiB
# executing  ------------------------------ 26.08 KiB/26.08 KiB
# referencing ------------------------------ 20.24 KiB/26.15 KiB
# asttokens  ------------------------------ 26.29 KiB/26.29 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# tenacity   ------------------------------ 14.88 KiB/27.51 KiB
# dataclasses-json ------------------------------ 14.87 KiB/28.01 KiB
# google-cloud-core ------------------------------ 28.66 KiB/28.66 KiB
# flatbuffers ------------------------------ 30.23 KiB/30.23 KiB
# google-crc32c ------------------------------ 30.90 KiB/31.73 KiB
# json5      ------------------------------ 32.00 KiB/33.25 KiB
# docstring-parser ------------------------------ 35.68 KiB/35.68 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 493.66 KiB/987.87 KiB
# jedi       ------------------------------ 525.38 KiB/1.50 MiB
# kubernetes ------------------------------ 1.45 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.28 MiB/2.30 MiB
#    Building pr1 @ file:///content/pr1
# ⠧ Preparing packages... (114/214)
# json-repair ------------------------------     0 B/20.20 KiB
# nodeenv    ------------------------------     0 B/21.79 KiB
# build      ------------------------------ 14.91 KiB/22.41 KiB
# pyjwt      ------------------------------     0 B/22.46 KiB
# markupsafe ------------------------------ 16.00 KiB/22.58 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# stack-data ------------------------------ 16.00 KiB/23.95 KiB
# executing  ------------------------------ 26.08 KiB/26.08 KiB
# referencing ------------------------------ 26.15 KiB/26.15 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# tenacity   ------------------------------ 14.88 KiB/27.51 KiB
# dataclasses-json ------------------------------ 14.87 KiB/28.01 KiB
# google-cloud-core ------------------------------ 28.66 KiB/28.66 KiB
# flatbuffers ------------------------------ 30.23 KiB/30.23 KiB
# google-crc32c ------------------------------ 30.90 KiB/31.73 KiB
# json5      ------------------------------ 33.25 KiB/33.25 KiB
# docstring-parser ------------------------------ 35.68 KiB/35.68 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 493.66 KiB/987.87 KiB
# jedi       ------------------------------ 525.38 KiB/1.50 MiB
#    Building pr1 @ file:///content/pr1
# ⠧ Preparing packages... (114/214)
# json-repair ------------------------------     0 B/20.20 KiB
# nodeenv    ------------------------------     0 B/21.79 KiB
# build      ------------------------------ 14.91 KiB/22.41 KiB
# pyjwt      ------------------------------ 14.88 KiB/22.46 KiB
# markupsafe ------------------------------ 16.00 KiB/22.58 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# stack-data ------------------------------ 16.00 KiB/23.95 KiB
# executing  ------------------------------ 26.08 KiB/26.08 KiB
# referencing ------------------------------ 26.15 KiB/26.15 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# tenacity   ------------------------------ 14.88 KiB/27.51 KiB
# dataclasses-json ------------------------------ 14.87 KiB/28.01 KiB
# google-cloud-core ------------------------------ 28.66 KiB/28.66 KiB
# flatbuffers ------------------------------ 30.23 KiB/30.23 KiB
# google-crc32c ------------------------------ 31.73 KiB/31.73 KiB
# json5      ------------------------------ 33.25 KiB/33.25 KiB
# docstring-parser ------------------------------ 35.68 KiB/35.68 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 493.66 KiB/987.87 KiB
# jedi       ------------------------------ 525.38 KiB/1.50 MiB
#    Building pr1 @ file:///content/pr1
# ⠧ Preparing packages... (114/214)
# json-repair ------------------------------     0 B/20.20 KiB
# nodeenv    ------------------------------     0 B/21.79 KiB
# build      ------------------------------ 14.91 KiB/22.41 KiB
# pyjwt      ------------------------------ 14.88 KiB/22.46 KiB
# markupsafe ------------------------------ 16.00 KiB/22.58 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# stack-data ------------------------------ 16.00 KiB/23.95 KiB
# executing  ------------------------------ 26.08 KiB/26.08 KiB
# referencing ------------------------------ 26.15 KiB/26.15 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# tenacity   ------------------------------ 14.88 KiB/27.51 KiB
# dataclasses-json ------------------------------ 14.87 KiB/28.01 KiB
# google-cloud-core ------------------------------ 28.66 KiB/28.66 KiB
# flatbuffers ------------------------------ 30.23 KiB/30.23 KiB
# google-crc32c ------------------------------ 31.73 KiB/31.73 KiB
# json5      ------------------------------ 33.25 KiB/33.25 KiB
# docstring-parser ------------------------------ 35.68 KiB/35.68 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 493.66 KiB/987.87 KiB
# jedi       ------------------------------ 525.38 KiB/1.50 MiB
#    Building pr1 @ file:///content/pr1
# ⠧ Preparing packages... (114/214)
# json-repair ------------------------------ 16.00 KiB/20.20 KiB
# nodeenv    ------------------------------ 14.88 KiB/21.79 KiB
# build      ------------------------------ 14.91 KiB/22.41 KiB
# pyjwt      ------------------------------ 14.88 KiB/22.46 KiB
# markupsafe ------------------------------ 22.58 KiB/22.58 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# stack-data ------------------------------ 16.00 KiB/23.95 KiB
# executing  ------------------------------ 26.08 KiB/26.08 KiB
# referencing ------------------------------ 26.15 KiB/26.15 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# tenacity   ------------------------------ 14.88 KiB/27.51 KiB
# dataclasses-json ------------------------------ 28.01 KiB/28.01 KiB
# google-cloud-core ------------------------------ 28.66 KiB/28.66 KiB
# flatbuffers ------------------------------ 30.23 KiB/30.23 KiB
# google-crc32c ------------------------------ 31.73 KiB/31.73 KiB
# json5      ------------------------------ 33.25 KiB/33.25 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 493.66 KiB/987.87 KiB
# jedi       ------------------------------ 541.66 KiB/1.50 MiB
# kubernetes ------------------------------ 1.45 MiB/1.90 MiB
#    Building pr1 @ file:///content/pr1
# ⠧ Preparing packages... (114/214)
# json-repair ------------------------------ 16.00 KiB/20.20 KiB
# nodeenv    ------------------------------ 14.88 KiB/21.79 KiB
# build      ------------------------------ 14.91 KiB/22.41 KiB
# pyjwt      ------------------------------ 14.88 KiB/22.46 KiB
# markupsafe ------------------------------ 22.58 KiB/22.58 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# stack-data ------------------------------ 16.00 KiB/23.95 KiB
# executing  ------------------------------ 26.08 KiB/26.08 KiB
# referencing ------------------------------ 26.15 KiB/26.15 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# dataclasses-json ------------------------------ 28.01 KiB/28.01 KiB
# google-cloud-core ------------------------------ 28.66 KiB/28.66 KiB
# flatbuffers ------------------------------ 30.23 KiB/30.23 KiB
# google-crc32c ------------------------------ 31.73 KiB/31.73 KiB
# json5      ------------------------------ 33.25 KiB/33.25 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 493.66 KiB/987.87 KiB
# jedi       ------------------------------ 541.66 KiB/1.50 MiB
# kubernetes ------------------------------ 1.45 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.29 MiB/2.30 MiB
#    Building pr1 @ file:///content/pr1
# ⠧ Preparing packages... (114/214)
# json-repair ------------------------------ 16.00 KiB/20.20 KiB
# nodeenv    ------------------------------ 14.88 KiB/21.79 KiB
# build      ------------------------------ 14.91 KiB/22.41 KiB
# pyjwt      ------------------------------ 14.88 KiB/22.46 KiB
# markupsafe ------------------------------ 22.58 KiB/22.58 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# stack-data ------------------------------ 16.00 KiB/23.95 KiB
# executing  ------------------------------ 26.08 KiB/26.08 KiB
# referencing ------------------------------ 26.15 KiB/26.15 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# dataclasses-json ------------------------------ 28.01 KiB/28.01 KiB
# google-cloud-core ------------------------------ 28.66 KiB/28.66 KiB
# flatbuffers ------------------------------ 30.23 KiB/30.23 KiB
# google-crc32c ------------------------------ 31.73 KiB/31.73 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 493.66 KiB/987.87 KiB
# jedi       ------------------------------ 541.66 KiB/1.50 MiB
# kubernetes ------------------------------ 1.45 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.29 MiB/2.30 MiB
# grpcio-tools ------------------------------ 2.32 MiB/2.36 MiB
#    Building pr1 @ file:///content/pr1
# ⠧ Preparing packages... (114/214)
# json-repair ------------------------------ 16.00 KiB/20.20 KiB
# nodeenv    ------------------------------ 14.88 KiB/21.79 KiB
# build      ------------------------------ 14.91 KiB/22.41 KiB
# pyjwt      ------------------------------ 14.88 KiB/22.46 KiB
# markupsafe ------------------------------ 22.58 KiB/22.58 KiB
# asgiref    ------------------------------ 16.00 KiB/23.27 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# stack-data ------------------------------ 16.00 KiB/23.95 KiB
# executing  ------------------------------ 26.08 KiB/26.08 KiB
# referencing ------------------------------ 26.15 KiB/26.15 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# dataclasses-json ------------------------------ 28.01 KiB/28.01 KiB
# google-cloud-core ------------------------------ 28.66 KiB/28.66 KiB
# flatbuffers ------------------------------ 30.23 KiB/30.23 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 493.66 KiB/987.87 KiB
# jedi       ------------------------------ 541.66 KiB/1.50 MiB
# kubernetes ------------------------------ 1.45 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.29 MiB/2.30 MiB
# grpcio-tools ------------------------------ 2.32 MiB/2.36 MiB
# langchain-community ------------------------------ 1.17 MiB/2.41 MiB
#    Building pr1 @ file:///content/pr1
# ⠧ Preparing packages... (114/214)
# types-requests ------------------------------     0 B/20.19 KiB
# json-repair ------------------------------ 16.00 KiB/20.20 KiB
# nodeenv    ------------------------------ 14.88 KiB/21.79 KiB
# build      ------------------------------ 14.91 KiB/22.41 KiB
# pyjwt      ------------------------------ 22.46 KiB/22.46 KiB
# markupsafe ------------------------------ 22.58 KiB/22.58 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# stack-data ------------------------------ 23.95 KiB/23.95 KiB
# executing  ------------------------------ 26.08 KiB/26.08 KiB
# referencing ------------------------------ 26.15 KiB/26.15 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# dataclasses-json ------------------------------ 28.01 KiB/28.01 KiB
# google-cloud-core ------------------------------ 28.66 KiB/28.66 KiB
# flatbuffers ------------------------------ 30.23 KiB/30.23 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 493.66 KiB/987.87 KiB
# jedi       ------------------------------ 541.66 KiB/1.50 MiB
# kubernetes ------------------------------ 1.46 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.30 MiB/2.30 MiB
# grpcio-tools ------------------------------ 2.32 MiB/2.36 MiB
#    Building pr1 @ file:///content/pr1
# ⠧ Preparing packages... (114/214)
# types-requests ------------------------------     0 B/20.19 KiB
# json-repair ------------------------------ 16.00 KiB/20.20 KiB
# nodeenv    ------------------------------ 14.88 KiB/21.79 KiB
# build      ------------------------------ 14.91 KiB/22.41 KiB
# pyjwt      ------------------------------ 22.46 KiB/22.46 KiB
# markupsafe ------------------------------ 22.58 KiB/22.58 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# stack-data ------------------------------ 23.95 KiB/23.95 KiB
# executing  ------------------------------ 26.08 KiB/26.08 KiB
# referencing ------------------------------ 26.15 KiB/26.15 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# dataclasses-json ------------------------------ 28.01 KiB/28.01 KiB
# google-cloud-core ------------------------------ 28.66 KiB/28.66 KiB
# flatbuffers ------------------------------ 30.23 KiB/30.23 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 493.66 KiB/987.87 KiB
# jedi       ------------------------------ 541.66 KiB/1.50 MiB
# kubernetes ------------------------------ 1.46 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.30 MiB/2.30 MiB
# grpcio-tools ------------------------------ 2.32 MiB/2.36 MiB
#    Building pr1 @ file:///content/pr1
# ⠇ Preparing packages... (121/214)
# distro     ------------------------------     0 B/19.80 KiB
# types-requests ------------------------------ 14.87 KiB/20.19 KiB
# json-repair ------------------------------ 16.00 KiB/20.20 KiB
# nodeenv    ------------------------------ 21.79 KiB/21.79 KiB
# build      ------------------------------ 14.91 KiB/22.41 KiB
# pyjwt      ------------------------------ 22.46 KiB/22.46 KiB
# markupsafe ------------------------------ 22.58 KiB/22.58 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# stack-data ------------------------------ 23.95 KiB/23.95 KiB
# referencing ------------------------------ 26.15 KiB/26.15 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# dataclasses-json ------------------------------ 28.01 KiB/28.01 KiB
# google-cloud-core ------------------------------ 28.66 KiB/28.66 KiB
# flatbuffers ------------------------------ 30.23 KiB/30.23 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 505.65 KiB/987.87 KiB
# jedi       ------------------------------ 541.66 KiB/1.50 MiB
# kubernetes ------------------------------ 1.46 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.30 MiB/2.30 MiB
# grpcio-tools ------------------------------ 2.32 MiB/2.36 MiB
#    Building pr1 @ file:///content/pr1
# ⠇ Preparing packages... (121/214)
# distro     ------------------------------     0 B/19.80 KiB
# types-requests ------------------------------ 14.87 KiB/20.19 KiB
# json-repair ------------------------------ 16.00 KiB/20.20 KiB
# nodeenv    ------------------------------ 21.79 KiB/21.79 KiB
# build      ------------------------------ 14.91 KiB/22.41 KiB
# pyjwt      ------------------------------ 22.46 KiB/22.46 KiB
# markupsafe ------------------------------ 22.58 KiB/22.58 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# stack-data ------------------------------ 23.95 KiB/23.95 KiB
# referencing ------------------------------ 26.15 KiB/26.15 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# dataclasses-json ------------------------------ 28.01 KiB/28.01 KiB
# google-cloud-core ------------------------------ 28.66 KiB/28.66 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 505.65 KiB/987.87 KiB
# jedi       ------------------------------ 541.66 KiB/1.50 MiB
# kubernetes ------------------------------ 1.46 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.30 MiB/2.30 MiB
# grpcio-tools ------------------------------ 2.32 MiB/2.36 MiB
# langchain-community ------------------------------ 1.18 MiB/2.41 MiB
#    Building pr1 @ file:///content/pr1
# ⠇ Preparing packages... (121/214)
# distro     ------------------------------     0 B/19.80 KiB
# types-requests ------------------------------ 14.87 KiB/20.19 KiB
# json-repair ------------------------------ 16.00 KiB/20.20 KiB
# nodeenv    ------------------------------ 21.79 KiB/21.79 KiB
# build      ------------------------------ 14.91 KiB/22.41 KiB
# pyjwt      ------------------------------ 22.46 KiB/22.46 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# stack-data ------------------------------ 23.95 KiB/23.95 KiB
# referencing ------------------------------ 26.15 KiB/26.15 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# dataclasses-json ------------------------------ 28.01 KiB/28.01 KiB
# google-cloud-core ------------------------------ 28.66 KiB/28.66 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 505.65 KiB/987.87 KiB
# jedi       ------------------------------ 541.66 KiB/1.50 MiB
# kubernetes ------------------------------ 1.46 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.30 MiB/2.30 MiB
# grpcio-tools ------------------------------ 2.35 MiB/2.36 MiB
# langchain-community ------------------------------ 1.18 MiB/2.41 MiB
# shapely    ------------------------------ 2.32 MiB/2.41 MiB
#    Building pr1 @ file:///content/pr1
# ⠇ Preparing packages... (121/214)
# distro     ------------------------------     0 B/19.80 KiB
# types-requests ------------------------------ 14.87 KiB/20.19 KiB
# json-repair ------------------------------ 16.00 KiB/20.20 KiB
# nodeenv    ------------------------------ 21.79 KiB/21.79 KiB
# build      ------------------------------ 14.91 KiB/22.41 KiB
# pyjwt      ------------------------------ 22.46 KiB/22.46 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# stack-data ------------------------------ 23.95 KiB/23.95 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# dataclasses-json ------------------------------ 28.01 KiB/28.01 KiB
# google-cloud-core ------------------------------ 28.66 KiB/28.66 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 505.65 KiB/987.87 KiB
# jedi       ------------------------------ 541.66 KiB/1.50 MiB
# kubernetes ------------------------------ 1.46 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.30 MiB/2.30 MiB
# grpcio-tools ------------------------------ 2.35 MiB/2.36 MiB
# langchain-community ------------------------------ 1.18 MiB/2.41 MiB
# shapely    ------------------------------ 2.32 MiB/2.41 MiB
# pypdfium2  ------------------------------ 2.44 MiB/2.73 MiB
#    Building pr1 @ file:///content/pr1
# ⠇ Preparing packages... (121/214)
# grpc-google-iam-v1 ------------------------------     0 B/18.80 KiB
# distro     ------------------------------ 14.88 KiB/19.80 KiB
# types-requests ------------------------------ 14.87 KiB/20.19 KiB
# json-repair ------------------------------ 16.00 KiB/20.20 KiB
# nodeenv    ------------------------------ 21.79 KiB/21.79 KiB
# build      ------------------------------ 14.91 KiB/22.41 KiB
# pyjwt      ------------------------------ 22.46 KiB/22.46 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# stack-data ------------------------------ 23.95 KiB/23.95 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# dataclasses-json ------------------------------ 28.01 KiB/28.01 KiB
# google-cloud-core ------------------------------ 28.66 KiB/28.66 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 505.65 KiB/987.87 KiB
# jedi       ------------------------------ 541.66 KiB/1.50 MiB
# kubernetes ------------------------------ 1.46 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.30 MiB/2.30 MiB
# grpcio-tools ------------------------------ 2.35 MiB/2.36 MiB
# langchain-community ------------------------------ 1.18 MiB/2.41 MiB
# shapely    ------------------------------ 2.32 MiB/2.41 MiB
#    Building pr1 @ file:///content/pr1
# ⠇ Preparing packages... (121/214)
# grpc-google-iam-v1 ------------------------------     0 B/18.80 KiB
# python-dotenv ------------------------------     0 B/19.40 KiB
# distro     ------------------------------ 14.88 KiB/19.80 KiB
# types-requests ------------------------------ 14.87 KiB/20.19 KiB
# json-repair ------------------------------ 16.00 KiB/20.20 KiB
# nodeenv    ------------------------------ 21.79 KiB/21.79 KiB
# build      ------------------------------ 14.91 KiB/22.41 KiB
# pyjwt      ------------------------------ 22.46 KiB/22.46 KiB
# asgiref    ------------------------------ 23.27 KiB/23.27 KiB
# requests-oauthlib ------------------------------ 14.86 KiB/23.61 KiB
# stack-data ------------------------------ 23.95 KiB/23.95 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# dataclasses-json ------------------------------ 28.01 KiB/28.01 KiB
# google-cloud-core ------------------------------ 28.66 KiB/28.66 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 505.65 KiB/987.87 KiB
# jedi       ------------------------------ 541.66 KiB/1.50 MiB
# kubernetes ------------------------------ 1.46 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.30 MiB/2.30 MiB
# grpcio-tools ------------------------------ 2.35 MiB/2.36 MiB
# langchain-community ------------------------------ 1.18 MiB/2.41 MiB
#    Building pr1 @ file:///content/pr1
# ⠇ Preparing packages... (121/214)
# grpc-google-iam-v1 ------------------------------     0 B/18.80 KiB
# python-dotenv ------------------------------     0 B/19.40 KiB
# distro     ------------------------------ 14.88 KiB/19.80 KiB
# types-requests ------------------------------ 14.87 KiB/20.19 KiB
# json-repair ------------------------------ 16.00 KiB/20.20 KiB
# nodeenv    ------------------------------ 21.79 KiB/21.79 KiB
# build      ------------------------------ 14.91 KiB/22.41 KiB
# pyjwt      ------------------------------ 22.46 KiB/22.46 KiB
# requests-oauthlib ------------------------------ 23.61 KiB/23.61 KiB
# stack-data ------------------------------ 23.95 KiB/23.95 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# dataclasses-json ------------------------------ 28.01 KiB/28.01 KiB
# google-cloud-core ------------------------------ 28.66 KiB/28.66 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 505.65 KiB/987.87 KiB
# jedi       ------------------------------ 541.66 KiB/1.50 MiB
# kubernetes ------------------------------ 1.46 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.30 MiB/2.30 MiB
# grpcio-tools ------------------------------ 2.35 MiB/2.36 MiB
# langchain-community ------------------------------ 1.18 MiB/2.41 MiB
# shapely    ------------------------------ 2.32 MiB/2.41 MiB
#    Building pr1 @ file:///content/pr1
# ⠇ Preparing packages... (121/214)
# grpc-google-iam-v1 ------------------------------     0 B/18.80 KiB
# python-dotenv ------------------------------     0 B/19.40 KiB
# distro     ------------------------------ 14.88 KiB/19.80 KiB
# types-requests ------------------------------ 14.87 KiB/20.19 KiB
# json-repair ------------------------------ 16.00 KiB/20.20 KiB
# nodeenv    ------------------------------ 21.79 KiB/21.79 KiB
# build      ------------------------------ 14.91 KiB/22.41 KiB
# pyjwt      ------------------------------ 22.46 KiB/22.46 KiB
# requests-oauthlib ------------------------------ 23.61 KiB/23.61 KiB
# stack-data ------------------------------ 23.95 KiB/23.95 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# dataclasses-json ------------------------------ 28.01 KiB/28.01 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 505.65 KiB/987.87 KiB
# jedi       ------------------------------ 541.66 KiB/1.50 MiB
# kubernetes ------------------------------ 1.46 MiB/1.90 MiB
# chroma-hnswlib ------------------------------ 2.30 MiB/2.30 MiB
# grpcio-tools ------------------------------ 2.35 MiB/2.36 MiB
# langchain-community ------------------------------ 1.18 MiB/2.41 MiB
# shapely    ------------------------------ 2.32 MiB/2.41 MiB
# pypdfium2  ------------------------------ 2.46 MiB/2.73 MiB
#    Building pr1 @ file:///content/pr1
# ⠇ Preparing packages... (121/214)
# grpc-google-iam-v1 ------------------------------     0 B/18.80 KiB
# python-dotenv ------------------------------     0 B/19.40 KiB
# distro     ------------------------------ 14.88 KiB/19.80 KiB
# types-requests ------------------------------ 14.87 KiB/20.19 KiB
# json-repair ------------------------------ 16.00 KiB/20.20 KiB
# nodeenv    ------------------------------ 21.79 KiB/21.79 KiB
# build      ------------------------------ 14.91 KiB/22.41 KiB
# pyjwt      ------------------------------ 22.46 KiB/22.46 KiB
# requests-oauthlib ------------------------------ 23.61 KiB/23.61 KiB
# stack-data ------------------------------ 23.95 KiB/23.95 KiB
# importlib-metadata ------------------------------ 26.34 KiB/26.34 KiB
# dataclasses-json ------------------------------ 28.01 KiB/28.01 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 505.65 KiB/987.87 KiB
# jedi       ------------------------------ 541.66 KiB/1.50 MiB
# kubernetes ------------------------------ 1.46 MiB/1.90 MiB
# grpcio-tools ------------------------------ 2.35 MiB/2.36 MiB
# langchain-community ------------------------------ 1.18 MiB/2.41 MiB
# shapely    ------------------------------ 2.32 MiB/2.41 MiB
# pypdfium2  ------------------------------ 2.46 MiB/2.73 MiB
# tokenizers ------------------------------ 2.30 MiB/2.86 MiB
#    Building pr1 @ file:///content/pr1
# ⠇ Preparing packages... (121/214)
# grpc-google-iam-v1 ------------------------------     0 B/18.80 KiB
# python-dotenv ------------------------------     0 B/19.40 KiB
# distro     ------------------------------ 14.88 KiB/19.80 KiB
# types-requests ------------------------------ 14.87 KiB/20.19 KiB
# json-repair ------------------------------ 16.00 KiB/20.20 KiB
# nodeenv    ------------------------------ 21.79 KiB/21.79 KiB
# build      ------------------------------ 14.91 KiB/22.41 KiB
# pyjwt      ------------------------------ 22.46 KiB/22.46 KiB
# requests-oauthlib ------------------------------ 23.61 KiB/23.61 KiB
# stack-data ------------------------------ 23.95 KiB/23.95 KiB
# dataclasses-json ------------------------------ 28.01 KiB/28.01 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 505.65 KiB/987.87 KiB
# jedi       ------------------------------ 541.66 KiB/1.50 MiB
# kubernetes ------------------------------ 1.46 MiB/1.90 MiB
# grpcio-tools ------------------------------ 2.35 MiB/2.36 MiB
# langchain-community ------------------------------ 1.18 MiB/2.41 MiB
# shapely    ------------------------------ 2.32 MiB/2.41 MiB
# pypdfium2  ------------------------------ 2.46 MiB/2.73 MiB
# tokenizers ------------------------------ 2.30 MiB/2.86 MiB
# psycopg2-binary ------------------------------ 2.44 MiB/2.88 MiB
#    Building pr1 @ file:///content/pr1
# ⠇ Preparing packages... (121/214)
# grpc-google-iam-v1 ------------------------------     0 B/18.80 KiB
# python-dotenv ------------------------------     0 B/19.40 KiB
# distro     ------------------------------ 14.88 KiB/19.80 KiB
# types-requests ------------------------------ 14.87 KiB/20.19 KiB
# json-repair ------------------------------ 16.00 KiB/20.20 KiB
# nodeenv    ------------------------------ 21.79 KiB/21.79 KiB
# build      ------------------------------ 14.91 KiB/22.41 KiB
# pyjwt      ------------------------------ 22.46 KiB/22.46 KiB
# requests-oauthlib ------------------------------ 23.61 KiB/23.61 KiB
# stack-data ------------------------------ 23.95 KiB/23.95 KiB
# dataclasses-json ------------------------------ 28.01 KiB/28.01 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 505.65 KiB/987.87 KiB
# jedi       ------------------------------ 541.66 KiB/1.50 MiB
# kubernetes ------------------------------ 1.46 MiB/1.90 MiB
# grpcio-tools ------------------------------ 2.35 MiB/2.36 MiB
# langchain-community ------------------------------ 1.18 MiB/2.41 MiB
# shapely    ------------------------------ 2.32 MiB/2.41 MiB
# pypdfium2  ------------------------------ 2.46 MiB/2.73 MiB
# tokenizers ------------------------------ 2.30 MiB/2.86 MiB
# psycopg2-binary ------------------------------ 2.44 MiB/2.88 MiB
#    Building pr1 @ file:///content/pr1
# ⠇ Preparing packages... (121/214)
# grpc-google-iam-v1 ------------------------------     0 B/18.80 KiB
# python-dotenv ------------------------------     0 B/19.40 KiB
# distro     ------------------------------ 14.88 KiB/19.80 KiB
# types-requests ------------------------------ 14.87 KiB/20.19 KiB
# json-repair ------------------------------ 16.00 KiB/20.20 KiB
# nodeenv    ------------------------------ 21.79 KiB/21.79 KiB
# build      ------------------------------ 22.41 KiB/22.41 KiB
# requests-oauthlib ------------------------------ 23.61 KiB/23.61 KiB
# stack-data ------------------------------ 23.95 KiB/23.95 KiB
# dataclasses-json ------------------------------ 28.01 KiB/28.01 KiB
# tzdata     ------------------------------ 266.92 KiB/338.63 KiB
# langchain  ------------------------------ 505.65 KiB/987.87 KiB
# jedi       ------------------------------ 541.66 KiB/1.50 MiB
# kubernetes ------------------------------ 1.46 MiB/1.90 MiB
# ...
# *   **Enhanced Robotics and Automation:** Integrating visual and textual information allows robots to understand instructions more naturally and interact with their environment more effectively.
#
# The advantages of multimodal LLMs are clear:
#
# *   **Richer Understanding:** By integrating multiple modalities, these models can achieve a more complete and nuanced understanding of the world.
# *   **Improved Accuracy:** The combination of different modalities can improve the accuracy of predictions and responses.
# *   **Enhanced User Experience:** Multimodal LLMs provide a more natural and intuitive user experience.
#
# The shift towards multimodal LLMs marks a significant advancement in AI, enabling more versatile and powerful applications across various industries.
#
# ## 3. Edge Deployment and On-Device LLMs
#
# In 2025, LLMs are no longer confined to the cloud. Advancements in model compression, quantization, and optimization have enabled the deployment of smaller, yet powerful, LLMs on edge devices such as smartphones, autonomous vehicles, and IoT devices. This trend towards edge deployment and on-device LLMs offers significant advantages:
#
# *   **Reduced Latency:** By processing data locally on the device, edge deployment eliminates the need to transmit data to a remote server, significantly reducing latency. This is crucial for real-time applications such as autonomous driving and virtual reality.
# *   **Enhanced Privacy:** Processing data on-device keeps sensitive information within the user's control, enhancing privacy and security. This is particularly important for applications that handle personal or confidential data.
# *   **Offline Functionality:** Edge deployment enables LLMs to function even when there is no internet connection. This is essential for applications that need to operate in remote or disconnected environments.
# *   **Lower Bandwidth Consumption:** By processing data locally, edge deployment reduces the amount of data that needs to be transmitted over the network, lowering bandwidth consumption and costs.
# *   **Increased Scalability:** Edge deployment distributes the processing load across multiple devices, increasing scalability and reducing the strain on central servers.
#
# Examples of edge deployment and on-device LLMs include:
#
# *   **Smartphones:** On-device LLMs power features such as smart assistants, language translation, and image recognition, all without requiring an internet connection.
# *   **Autonomous Vehicles:** Edge-based LLMs enable autonomous vehicles to process sensor data in real-time, making critical driving decisions without relying on cloud connectivity.
# *   **IoT Devices:** LLMs embedded in IoT devices enable them to understand and respond to voice commands, analyze sensor data, and automate tasks, all while maintaining privacy and security.
#
# The move towards edge deployment and on-device LLMs represents a paradigm shift in AI, bringing the power of LLMs closer to the user and enabling a new generation of intelligent devices.
#
# ## 4. Advanced Reasoning and Problem-Solving Capabilities
#
# LLMs in 2025 demonstrate significantly improved reasoning and problem-solving capabilities compared to their predecessors. They are capable of handling complex tasks that require multi-step reasoning, common-sense knowledge, and the ability to learn from limited examples. This advancement is driven by innovations in model architecture and training techniques:
#
# *   **Multi-Step Reasoning:** LLMs can break down complex problems into smaller, more manageable steps, and reason through each step to arrive at a solution. This is crucial for tasks such as planning, decision-making, and problem-solving.
# *   **Common-Sense Knowledge:** LLMs are equipped with a vast amount of common-sense knowledge, allowing them to understand and reason about everyday situations. This enables them to make inferences, draw conclusions, and provide relevant and helpful responses.
# *   **Learning from Limited Examples:** Techniques like few-shot learning and meta-learning allow LLMs to learn from limited examples and generalize to new situations. This reduces the need for large training datasets and makes it easier to adapt LLMs to new tasks.
# *   **Reinforcement Learning from Human Feedback (RLHF):** RLHF is used to fine-tune LLMs based on human preferences, making them more aligned with human values and goals. This improves the quality of the LLM's responses and makes them more helpful and informative.
# *   **Self-Supervised Learning:** Self-supervised learning techniques allow LLMs to learn from unlabeled data, enabling them to acquire knowledge and skills without explicit human supervision.
#
# Examples of advanced reasoning and problem-solving capabilities include:
#
# *   **Complex Task Automation:** LLMs can automate complex tasks that require reasoning, planning, and decision-making, such as managing supply chains, optimizing logistics, and coordinating projects.
# *   **Scientific Discovery:** LLMs can assist scientists in analyzing data, generating hypotheses, and designing experiments, accelerating the pace of scientific discovery.
# *   **Personalized Education:** LLMs can provide personalized education tailored to individual student's needs and learning styles, improving learning outcomes and engagement.
#
# The enhanced reasoning and problem-solving abilities of LLMs in 2025 are transforming industries and enabling new possibilities across various domains.
#
# ## 5. Explainable AI (XAI) and Interpretability
#
# Addressing the "black box" nature of earlier LLMs, a strong emphasis is now placed on explainability and interpretability. Techniques like attention visualization, causal inference, and model distillation are used to understand how LLMs arrive at their decisions, making them more transparent and trustworthy.
#
# Key approaches to XAI and interpretability include:
#
# *   **Attention Visualization:** Visualizing the attention weights of LLMs allows users to see which parts of the input are most relevant to the model's decision. This provides insights into how the model is processing information and making predictions.
# *   **Causal Inference:** Causal inference techniques are used to identify the causal relationships between different variables in the model. This helps to understand the underlying mechanisms that drive the model's behavior and to identify potential biases or unintended consequences.
# *   **Model Distillation:** Model distillation involves training a smaller, more interpretable model to mimic the behavior of a larger, more complex model. This allows users to gain insights into the decision-making process of the larger model without sacrificing accuracy.
# *   **SHAP (SHapley Additive exPlanations) values:** These are used to explain the output of a machine learning model by assigning each feature a value representing its contribution to the prediction.
#
# The benefits of XAI and interpretability are significant:
#
# *   **Increased Trustworthiness:** By understanding how LLMs make decisions, users can have greater confidence in their reliability and accuracy.
# *   **Improved Debugging:** Explainability helps to identify and correct errors in the model, improving its overall performance.
# *   **Enhanced Compliance:** Transparency is crucial for compliance with regulations and ethical guidelines.
# *   **Greater User Acceptance:** Explainable AI fosters greater user acceptance by building trust and understanding.
#
# The focus on XAI and interpretability is essential for ensuring the responsible and ethical deployment of LLMs in critical applications.
#
# ## 6. Robustness Against Adversarial Attacks
#
# LLMs in 2025 are significantly more resilient to adversarial attacks compared to earlier models. Research has led to the development of defense mechanisms that can detect and mitigate adversarial inputs, preventing malicious actors from manipulating model behavior. This is crucial for ensuring the reliability and security of LLMs in critical applications:
#
# *   **Adversarial Training:** LLMs are trained on adversarial examples, which are specifically designed to fool the model. This helps the model to learn to recognize and defend against adversarial attacks.
# *   **Input Sanitization:** Input sanitization techniques are used to detect and remove potentially malicious inputs before they are fed into the model. This helps to prevent adversarial attacks from succeeding in the first place.
# *   **Anomaly Detection:** Anomaly detection techniques are used to identify inputs that are significantly different from the training data. These inputs may be adversarial attacks, and the model can take appropriate action to mitigate the risk.
# *   **Regularization Techniques:** Various regularization techniques help in preventing overfitting and increase model generalization.
#
# The importance of robustness against adversarial attacks cannot be overstated:
#
# *   **Ensuring Reliability:** Robustness ensures that LLMs can be relied upon to provide accurate and consistent results, even in the face of malicious attacks.
# *   **Protecting Security:** Robustness protects against security vulnerabilities that could be exploited by malicious actors to gain unauthorized access to sensitive information or to disrupt critical systems.
# *   **Maintaining Trust:** Robustness maintains user trust in LLMs by ensuring that they are not easily manipulated or fooled.
#
# The development of robust LLMs is essential for their safe and reliable deployment in a wide range of applications.
#
# ## 7. Integration with Knowledge Graphs and External Tools
#
# LLMs are increasingly integrated with external knowledge graphs and tools. This allows them to access and leverage structured knowledge, perform calculations, and interact with real-world systems.
#
# Key benefits of this integration include:
#
# *   **Access to Structured Knowledge:** Integration with knowledge graphs provides LLMs with access to a vast amount of structured knowledge, enabling them to answer questions more accurately and comprehensively.
# *   **Ability to Perform Calculations:** Integration with external tools allows LLMs to perform calculations, such as arithmetic operations, statistical analysis, and financial modeling.
# *   **Interaction with Real-World Systems:** Integration with real-world systems enables LLMs to control robots, manage IoT devices, and automate other physical tasks.
#
# Examples of integration with knowledge graphs and external tools include:
#
# *   **Financial Database Access:** An LLM can access a financial database to provide real-time stock quotes and financial analysis.
# *   **Robotic Arm Control:** An LLM can control a robotic arm to perform physical tasks, such as assembling products or manipulating objects.
# *   **API integration**: LLMs can use APIs to connect to and interact with third-party services and applications, like calling weather APIs to answer weather-related questions.
#
# The integration of LLMs with external knowledge graphs and tools expands their capabilities and enables them to solve a wider range of problems.
#
# ## 8. Ethical Considerations and Bias Mitigation
#
# Ethical considerations are paramount in the development and deployment of LLMs in 2025. Extensive research and development efforts are focused on mitigating bias in LLMs and ensuring responsible use:
#
# *   **Data Augmentation:** Data augmentation techniques are used to create more balanced training datasets, reducing bias in the model.
# *   **Adversarial Training:** Adversarial training can be used to make LLMs more robust to biased inputs.
# *   **Fairness-Aware Model Design:** Fairness-aware model design incorporates fairness metrics into the model training process, ensuring that the model is fair to all groups.
# *   **Regularization and Constraints**: Implementing methods to prevent the model from relying on biased features.
# *   **Red Teaming**: Running simulations with teams trying to find biases in the LLM.
#
# Regulations and guidelines are also in place to govern the development and deployment of LLMs, ensuring that they are used responsibly and ethically. These regulations address issues such as:
#
# *   **Data Privacy:** Protecting the privacy of individuals whose data is used to train LLMs.
# *   **Bias and Fairness:** Ensuring that LLMs are fair and do not discriminate against any group.
# *   **Transparency and Accountability:** Making LLMs transparent and accountable for their decisions.
#
# The commitment to ethical considerations and bias mitigation is essential for ensuring that LLMs are used for the benefit of society.
#
# ## 9. Personalized and Adaptive LLMs
#
# LLMs are becoming increasingly personalized and adaptive. They can learn from user interactions and tailor their responses to individual preferences and needs.
#
# Techniques used to achieve personalization and adaptation include:
#
# *   **Meta-Learning:** Meta-learning allows LLMs to learn how to learn, enabling them to adapt to new tasks and environments with minimal training data.
# *   **Few-Shot Learning:** Few-shot learning allows LLMs to learn from limited examples, making it easier to personalize the model to individual users.
# *   **Continual Learning:** Continual learning allows LLMs to continuously learn from new data without forgetting what they have already learned, enabling them to adapt to changing user preferences and needs.
# *   **User Feedback Loops**: Integrating user feedback to continuously improve and personalize the LLM's responses.
#
# The benefits of personalized and adaptive LLMs are significant:
#
# *   **Improved User Experience:** Personalized LLMs provide a more tailored and relevant user experience.
# *   **Increased Engagement:** Personalized LLMs are more engaging and motivating for users.
# *   **Enhanced Learning Outcomes:** Personalized LLMs can improve learning outcomes by tailoring the learning experience to individual needs and learning styles.
#
# The trend towards personalized and adaptive LLMs is transforming the way we interact with AI, making it more user-friendly and effective.
#
# ## 10. Automated LLM Development and Optimization
#
# The process of developing and optimizing LLMs has become more automated in 2025. Tools and platforms are available that can automatically generate training data, fine-tune model parameters, and deploy LLMs to different environments.
#
# Key features of automated LLM development and optimization include:
#
# *   **Automated Data Generation:** Tools can automatically generate training data, reducing the need for manual data collection and labeling.
# *   **Automated Model Fine-Tuning:** Platforms can automatically fine-tune model parameters, optimizing the model for specific tasks and environments.
# *   **Automated Deployment:** Tools can automatically deploy LLMs to different environments, such as cloud servers, edge devices, and mobile apps.
# *   **Hyperparameter Optimization**: Automating the process of finding the best hyperparameter configuration for a given model.
#
# The benefits of automated LLM development and optimization are clear:
#
# *   **Democratized Access:** Automated tools democratize access to LLM technology, making it easier for developers to build and deploy LLMs.
# *   **Reduced Development Time:** Automation reduces the time and effort required to develop and optimize LLMs.
# *   **Increased Efficiency:** Automation improves the efficiency of the LLM development process.
#
# The automation of LLM development and optimization is accelerating the pace of innovation and making LLM technology more accessible to a wider audience.
#
#
#
# [2025-03-13 09:58:56][✅ AGENT 'AI LLMS REPORTING ANALYST
# ' COMPLETED TASK]: 2025-03-13 09:58:56.681624
#
# [2025-03-13 09:58:56][✅ TASK COMPLETED: REVIEW THE CONTEXT YOU GOT AND EXPAND EACH TOPIC INTO A FULL SECTION FOR A REPORT. MAKE SURE THE REPORT IS DETAILED AND CONTAINS ANY AND ALL RELEVANT INFORMATION.
# ]: 2025-03-13 09:58:56.682372
#
# [2025-03-13 09:58:56][✅ CREW 'CREW' COMPLETED, 6320AAC7-1BF4-477C-BA9E-529F075E603F]: 2025-03-13 09:58:56.696912

# %% [markdown]
# # Testing

# %%
# !crewai test -n 2 -m gpt-4o-mini
# Out:
# Testing the crew for 2 iterations with model gpt-4o-mini
# Traceback (most recent call last):
#   File "/content/pr1/src/pr1/main.py", line 63, in test
#     Pr1().crew().test(n_iterations=int(sys.argv[1]), openai_model_name=sys.argv[2], inputs=inputs)
# TypeError: Crew.test() got an unexpected keyword argument 'openai_model_name'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/pr1/.venv/bin/test", line 10, in <module>
#     sys.exit(test())
#              ^^^^^^
#   File "/content/pr1/src/pr1/main.py", line 66, in test
#     raise Exception(f"An error occurred while testing the crew: {e}")
# Exception: An error occurred while testing the crew: Crew.test() got an unexpected keyword argument 'openai_model_name'
# An error occurred while testing the crew: Command '['uv', 'run', 'test', '2', 'gpt-4o-mini']' returned non-zero exit status 1.

# %%
# For testing we should have openaiai gpt-4o models
